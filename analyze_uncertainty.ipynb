# %%
import os
import torch
import matplotlib.pyplot as plt
from tqdm import tqdm
from PIL import Image
from torch.utils.data import DataLoader
from torchvision import transforms
from collections import defaultdict

from models.Resnet_LSTM import ResNetLSTM
from datasets.data_loader import WikiArtDataset, collate_skip_none
from datasets.csv_data_loader import csv_Dataset

# %%
def analyze_model_uncertainty(task="artist", file="Artist", top_n=20):
    # === CONFIG ===
    image_root = os.path.join("datasets", "wikiart")
    class_file = os.path.join("datasets", file, f"{task}_class.txt")

    if task == "artist":
        train_file = os.path.join("datasets", file, f"{task}_train")
        val_file = os.path.join("datasets", file, f"{task}_val")
    elif task in ["genre", "style"]:
        train_file = os.path.join("datasets", file, f"{task}_train.csv")
        val_file = os.path.join("datasets", file, f"{task}_val.csv")
    else:
        raise ValueError(f"Unsupported task: {task}")

    model_path = os.path.join("checkpoints", f"{task}_best_model.pt")
    outlier_dir = "outliers"
    os.makedirs(outlier_dir, exist_ok=True)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    class_names = [line.strip() for line in open(class_file, encoding='utf-8')]
    num_classes = len(class_names)

    transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])
    ])

    # === Load data and model ===
    if task == "artist":
        dataset = WikiArtDataset(val_file, image_root, transform)
    elif task in ["genre", "style"]:
        dataset = csv_Dataset(val_file, image_root, transform)

    dataloader = DataLoader(dataset, batch_size=1, shuffle=False, collate_fn=collate_skip_none)

    model = ResNetLSTM(num_classes=num_classes)
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.to(device)
    model.eval()

    # === Analyze uncertainty ===
    entropy_list = []
    softmax = torch.nn.Softmax(dim=1)
    error_count = defaultdict(int)
    entropy_count = defaultdict(int)
    total_count = defaultdict(int)

    with torch.no_grad():
        for idx, batch in enumerate(tqdm(dataloader, desc="Analyzing")):
            if batch is None:
                continue
            image, label = batch
            image, label = image.to(device), label.to(device)
            output = model(image)
            prob = softmax(output)

            entropy = -torch.sum(prob * torch.log(prob + 1e-9), dim=1).item()
            predicted = prob.argmax(dim=1).item()
            true_label = label.item()

            entropy_list.append((entropy, predicted, true_label, dataset.samples[idx][0]))

            true_class = class_names[true_label]
            total_count[true_class] += 1
            if predicted != true_label:
                error_count[true_class] += 1
            if entropy > 2.0:  # ⬅️ 可以視情況調整 entropy 門檻
                entropy_count[true_class] += 1

    # === Sort by highest entropy (most uncertain) ===
    entropy_list.sort(reverse=True, key=lambda x: x[0])

    # === Save top-N outliers ===
    print(f"\nTop {top_n} most uncertain predictions (possible outliers):")
    for i in range(min(top_n, len(entropy_list))):
        ent, pred, true, path = entropy_list[i]
        print(f"[{i+1}] Entropy: {ent:.4f} | True: {true} | Pred: {pred} | {path}")
        try:
            img = Image.open(path).convert("RGB")
            plt.imshow(img)
            plt.title(f"Entropy: {ent:.2f}\nTrue: {true} | Pred: {pred}")
            plt.axis("off")
            plt.savefig(os.path.join(outlier_dir, f"{task}_outlier_{i+1}.png"))
            plt.close()
        except Exception as e:
            print(f"Failed to save image: {path}, error: {e}")

    # === Output class-wise summary ===
    print("\nClass-wise uncertainty and error analysis:")
    print(f"{'Class':<30} {'Errors':<7} {'Uncertain':<10} {'Total':<6} {'Err%':<6} {'Unc%':<6}")
    for cls in class_names:
        total = total_count[cls]
        if total == 0: continue
        err = error_count[cls]
        ent = entropy_count[cls]
        print(f"{cls:<30} {err:<7} {ent:<10} {total:<6} {err/total:.2%} {ent/total:.2%}")

# %%
analyze_model_uncertainty(file="Artist", task="artist", top_n=20)
# Out:
# Available images: 5706 / Total: 5706, Missing: 0
# c:\Users\user\anaconda3\envs\cuda\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\user\anaconda3\envs\cuda\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Analyzing: 100%|██████████| 5706/5706 [12:21<00:00,  7.69it/s]
# Top 20 most uncertain predictions (possible outliers):
# [1] Entropy: 2.2149 | True: 14 | Pred: 21 | datasets\wikiart\Realism\nicholas-roerich_study-of-landscape.jpg
# [2] Entropy: 2.1996 | True: 13 | Pred: 4 | datasets\wikiart\Expressionism\martiros-saryan_a-bull-1922.jpg
# [3] Entropy: 2.1906 | True: 15 | Pred: 20 | datasets\wikiart\Expressionism\pablo-picasso_self-portrait-1901.jpg
# [4] Entropy: 2.1607 | True: 16 | Pred: 1 | datasets\wikiart\Post_Impressionism\paul-cezanne_madame-cezanne-in-a-striped-rob.jpg
# [5] Entropy: 2.1543 | True: 4 | Pred: 8 | datasets\wikiart\Impressionism\claude-monet_the-dinner-1869.jpg
# [6] Entropy: 2.1357 | True: 15 | Pred: 3 | datasets\wikiart\Expressionism\pablo-picasso_madame-soler-1905.jpg
# [7] Entropy: 2.1291 | True: 11 | Pred: 7 | datasets\wikiart\Realism\john-singer-sargent_the-daughters-of-edward-darley-boit-1882.jpg
# [8] Entropy: 2.0827 | True: 7 | Pred: 22 | datasets\wikiart\Romanticism\gustave-dore_illustration-for-charles-perraults-bluebeard.jpg
# [9] Entropy: 2.0081 | True: 8 | Pred: 1 | datasets\wikiart\Realism\ilya-repin_the-merchant-kalashnikov-1868.jpg
# [10] Entropy: 2.0030 | True: 21 | Pred: 20 | datasets\wikiart\Expressionism\salvador-dali_untitled-female-nude-on-a-palette.jpg
# [11] Entropy: 1.9961 | True: 16 | Pred: 16 | datasets\wikiart\Romanticism\paul-cezanne_the-artist-s-mother-1867.jpg
# [12] Entropy: 1.9890 | True: 5 | Pred: 5 | datasets\wikiart\Impressionism\edgar-degas_group-of-dancers-1.jpg
# [13] Entropy: 1.9880 | True: 14 | Pred: 20 | datasets\wikiart\Symbolism\nicholas-roerich_forging-the-sword-nibelung-1941.jpg
# [14] Entropy: 1.9758 | True: 3 | Pred: 3 | datasets\wikiart\Impressionism\childe-hassam_childe-hassam-a-shower-bonaparte-street.jpg
# [15] Entropy: 1.9744 | True: 11 | Pred: 16 | datasets\wikiart\Impressionism\john-singer-sargent_at-torre-galli-ladies-in-a-garden-1910.jpg
# [16] Entropy: 1.9733 | True: 3 | Pred: 4 | datasets\wikiart\Impressionism\childe-hassam_the-water-garden.jpg
# [17] Entropy: 1.9694 | True: 2 | Pred: 2 | datasets\wikiart\Impressionism\camille-pissarro_portrait-of-pere-papeille-pontoise.jpg
# [18] Entropy: 1.9645 | True: 10 | Pred: 16 | datasets\wikiart\Realism\ivan-shishkin_stones.jpg
# [19] Entropy: 1.9619 | True: 10 | Pred: 22 | datasets\wikiart\Realism\ivan-shishkin_ivan-shishkin-and-a-guinet-in-the-studio-on-the-island-of-valaam-1860.jpg
# [20] Entropy: 1.9576 | True: 16 | Pred: 13 | datasets\wikiart\Romanticism\paul-cezanne_the-four-seasons-winter-1861.jpg
#
# Class-wise uncertainty and error analysis:
# Class                          Errors  Uncertain  Total  Err%   Unc%
# 0 Albrecht_Durer               36      0          248    14.52% 0.00%
# 1 Boris_Kustodiev              61      0          189    32.28% 0.00%
# 2 Camille_Pissarro             58      0          266    21.80% 0.00%
# 3 Childe_Hassam                22      0          165    13.33% 0.00%
# 4 Claude_Monet                 59      1          400    14.75% 0.25%
# 5 Edgar_Degas                  48      0          183    26.23% 0.00%
# 6 Eugene_Boudin                16      0          166    9.64% 0.00%
# 7 Gustave_Dore                 14      1          225    6.22% 0.44%
# 8 Ilya_Repin                   49      1          161    30.43% 0.62%
# 9 Ivan_Aivazovsky              10      0          173    5.78% 0.00%
# 10 Ivan_Shishkin               23      0          156    14.74% 0.00%
# 11 John_Singer_Sargent         64      1          235    27.23% 0.43%
# 12 Marc_Chagall                39      0          229    17.03% 0.00%
# 13 Martiros_Saryan             45      1          172    26.16% 0.58%
# 14 Nicholas_Roerich            65      1          545    11.93% 0.18%
# 15 Pablo_Picasso               73      2          228    32.02% 0.88%
# 16 Paul_Cezanne                38      1          173    21.97% 0.58%
# 17 Pierre_Auguste_Renoir       43      0          420    10.24% 0.00%
# 18 Pyotr_Konchalovsky          40      0          275    14.55% 0.00%
# 19 Raphael_Kirchner            15      0          154    9.74% 0.00%
# 20 Rembrandt                   18      0          233    7.73% 0.00%
# 21 Salvador_Dali               46      1          143    32.17% 0.70%
# 22 Vincent_van_Gogh            64      0          567    11.29% 0.00%

# %%
analyze_model_uncertainty(file="Genre", task="genre", top_n=20)
# Out:
# Available images: 19492 / Total: 19492, Missing: 0
# c:\Users\user\anaconda3\envs\cuda\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\user\anaconda3\envs\cuda\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Analyzing: 100%|██████████| 19492/19492 [08:20<00:00, 38.98it/s]
# Top 20 most uncertain predictions (possible outliers):
# [1] Entropy: 2.1726 | True: 3 | Pred: 2 | datasets\wikiart\Symbolism\mikhail-vrubel_head-of-demon-1.jpg
# [2] Entropy: 2.1573 | True: 9 | Pred: 2 | datasets\wikiart\Synthetic_Cubism\georges-braque_the-clarinet-valse-1912.jpg
# [3] Entropy: 2.1527 | True: 0 | Pred: 2 | datasets\wikiart\Expressionism\ilka-gedo_portrait-of-kl-ri-horv-th-1972.jpg
# [4] Entropy: 2.1480 | True: 1 | Pred: 2 | datasets\wikiart\Impressionism\john-singer-sargent_venetian-canal.jpg
# [5] Entropy: 2.1473 | True: 2 | Pred: 2 | datasets\wikiart\Expressionism\balthus_girl-at-the-window-1955.jpg
# [6] Entropy: 2.1336 | True: 5 | Pred: 7 | datasets\wikiart\Pointillism\henri-edmond-cross_aguttes.jpg
# [7] Entropy: 2.1285 | True: 0 | Pred: 4 | datasets\wikiart\Abstract_Expressionism\philip-guston_close-up-iii-1961.jpg
# [8] Entropy: 2.1233 | True: 3 | Pred: 3 | datasets\wikiart\Expressionism\m.c.-escher_wateringcan.jpg
# [9] Entropy: 2.1232 | True: 7 | Pred: 2 | datasets\wikiart\Naive_Art_Primitivism\marc-chagall_study-to-jacob-wrestling-with-the-angel-1.jpg
# [10] Entropy: 2.1210 | True: 0 | Pred: 4 | datasets\wikiart\Expressionism\ilka-gedo_nodding-artificial-flower-red-version-1972.jpg
# [11] Entropy: 2.1176 | True: 2 | Pred: 2 | datasets\wikiart\Expressionism\salvador-dali_grandmother-ana-sewing.jpg
# [12] Entropy: 2.1166 | True: 7 | Pred: 2 | datasets\wikiart\Naive_Art_Primitivism\marc-chagall_solomon-1956.jpg
# [13] Entropy: 2.1111 | True: 2 | Pred: 3 | datasets\wikiart\Cubism\jacques-villon_the-equilibrist-l-equilibriste-1913.jpg
# [14] Entropy: 2.1103 | True: 0 | Pred: 8 | datasets\wikiart\Pop_Art\nicholas-krushenick_untitled-1998.jpg
# [15] Entropy: 2.1073 | True: 8 | Pred: 0 | datasets\wikiart\Expressionism\dimitris-mytaras_ortrait-of-a-woman.jpg
# [16] Entropy: 2.1019 | True: 2 | Pred: 2 | datasets\wikiart\Expressionism\ernst-ludwig-kirchner_hungarian-dance.jpg
# [17] Entropy: 2.1001 | True: 7 | Pred: 2 | datasets\wikiart\Art_Nouveau_Modern\jacek-malczewski_angel-and-the-little-shepherd-boy-1.jpg
# [18] Entropy: 2.0962 | True: 0 | Pred: 2 | datasets\wikiart\Abstract_Expressionism\hassel-smith_untitled-yellow-1960.jpg
# [19] Entropy: 2.0961 | True: 6 | Pred: 0 | datasets\wikiart\Expressionism\victor-brauner_head-1944.jpg
# [20] Entropy: 2.0955 | True: 4 | Pred: 2 | datasets\wikiart\Rococo\george-morland_winter-landscape.jpg
#
# Class-wise uncertainty and error analysis:
# Class                          Errors  Uncertain  Total  Err%   Unc%
# 0 abstract_painting            314     13         1490   21.07% 0.87%
# 1 cityscape                    461     4          1380   33.41% 0.29%
# 2 genre_painting               1511    22         3257   46.39% 0.68%
# 3 illustration                 357     10         570    62.63% 1.75%
# 4 landscape                    768     8          4007   19.17% 0.20%
# 5 nude_painting                402     2          576    69.79% 0.35%
# 6 portrait                     843     12         4233   19.91% 0.28%
# 7 religious_painting           842     8          1961   42.94% 0.41%
# 8 sketch_and_study             495     2          1182   41.88% 0.17%
# 9 still_life                   382     9          836    45.69% 1.08%

# %%
analyze_model_uncertainty(file="Style", task="style", top_n=20)
# Out:
# Available images: 24421 / Total: 24421, Missing: 0
# c:\Users\user\anaconda3\envs\cuda\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\user\anaconda3\envs\cuda\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Analyzing: 100%|██████████| 24421/24421 [12:10<00:00, 33.43it/s]
# Top 20 most uncertain predictions (possible outliers):
# [1] Entropy: 3.0683 | True: 12 | Pred: 8 | datasets\wikiart\Impressionism\joaquã­n-sorolla_adobe-houses.jpg
# [2] Entropy: 3.0169 | True: 12 | Pred: 6 | datasets\wikiart\Impressionism\auguste-rodin_walking-man-1900.jpg
# [3] Entropy: 2.9974 | True: 8 | Pred: 8 | datasets\wikiart\Early_Renaissance\piero-della-francesca_constantine-s-victory-over-maxentius-detail-1(1).jpg
# [4] Entropy: 2.9783 | True: 12 | Pred: 19 | datasets\wikiart\Impressionism\gustave-caillebotte_garden-rose-and-blue-forget-me-nots-in-a-vase.jpg
# [5] Entropy: 2.9654 | True: 21 | Pred: 15 | datasets\wikiart\Realism\ivan-kramskoy_kramsky-who-writes-a-portrait-of-his-daughter-sofia-ivanovna-archaeology-from-marriage-juncker-1884.jpg
# [6] Entropy: 2.9573 | True: 0 | Pred: 24 | datasets\wikiart\Abstract_Expressionism\gerhard-richter_wallace-bournes.jpg
# [7] Entropy: 2.9477 | True: 6 | Pred: 19 | datasets\wikiart\Contemporary_Realism\eric-fischl_once-where-we-looked-to-put-down.jpg
# [8] Entropy: 2.9362 | True: 21 | Pred: 18 | datasets\wikiart\Realism\vasily-polenov_red-sail-1911.jpg
# [9] Entropy: 2.9332 | True: 12 | Pred: 20 | datasets\wikiart\Impressionism\childe-hassam_avenue-of-the-allies-1.jpg
# [10] Entropy: 2.9230 | True: 26 | Pred: 19 | datasets\wikiart\Ukiyo_e\katsushika-hokusai_oni-pelted-by-beans.jpg
# [11] Entropy: 2.9167 | True: 24 | Pred: 19 | datasets\wikiart\Symbolism\george-frederick-watts_clytie(1).jpg
# [12] Entropy: 2.9093 | True: 9 | Pred: 12 | datasets\wikiart\Expressionism\dimitris-mytaras_ortrait-of-a-woman.jpg
# [13] Entropy: 2.9079 | True: 19 | Pred: 0 | datasets\wikiart\Pop_Art\patrick-procktor_two-chinese-generals-1968.jpg
# [14] Entropy: 2.8791 | True: 21 | Pred: 26 | datasets\wikiart\Realism\charles-francois-daubigny_river-landscape-creek-crossing-a-wooded-meadow.jpg
# [15] Entropy: 2.8752 | True: 0 | Pred: 3 | datasets\wikiart\Abstract_Expressionism\willem-de-kooning_untitled-verso-untitled.jpg
# [16] Entropy: 2.8742 | True: 3 | Pred: 3 | datasets\wikiart\Art_Nouveau_Modern\aubrey-beardsley_the-battle-of-the-beaux-and-the-belles-1896.jpg
# [17] Entropy: 2.8725 | True: 0 | Pred: 6 | datasets\wikiart\Abstract_Expressionism\louise-nevelson_night-tree-1971.jpg
# [18] Entropy: 2.8702 | True: 14 | Pred: 24 | datasets\wikiart\Minimalism\lee-ufan_relatum-discussion-2003.jpg
# [19] Entropy: 2.8609 | True: 12 | Pred: 12 | datasets\wikiart\Impressionism\gregoire-boonzaier_a-large-oak-tree-in-front-of-houses-1985.jpg
# [20] Entropy: 2.8583 | True: 6 | Pred: 19 | datasets\wikiart\Contemporary_Realism\neil-welliver_late-light.jpg
#
# Class-wise uncertainty and error analysis:
# Class                          Errors  Uncertain  Total  Err%   Unc%
# 0 Abstract_Expressionism       382     143        834    45.80% 17.15%
# 1 Action_painting              29      4          29     100.00% 13.79%
# 2 Analytical_Cubism            33      8          33     100.00% 24.24%
# 3 Art_Nouveau                  681     184        1300   52.38% 14.15%
# 4 Baroque                      489     81         1272   38.44% 6.37%
# 5 Color_Field_Painting         133     12         484    27.48% 2.48%
# 6 Contemporary_Realism         144     50         144    100.00% 34.72%
# 7 Cubism                       269     70         670    40.15% 10.45%
# 8 Early_Renaissance            231     80         417    55.40% 19.18%
# 9 Expressionism                1007    270        2020   49.85% 13.37%
# 10 Fauvism                     244     55         280    87.14% 19.64%
# 11 High_Renaissance            319     84         402    79.35% 20.90%
# 12 Impressionism               1084    110        3918   27.67% 2.81%
# 13 Mannerism_Late_Renaissance  286     62         383    74.67% 16.19%
# 14 Minimalism                  106     30         401    26.43% 7.48%
# 15 Naive_Art_Primitivism       404     126        721    56.03% 17.48%
# 16 New_Realism                 94      21         94     100.00% 22.34%
# 17 Northern_Renaissance        287     125        765    37.52% 16.34%
# 18 Pointillism                 58      33         153    37.91% 21.57%
# 19 Pop_Art                     246     100        444    55.41% 22.52%
# 20 Post_Impressionism          1064    158        1935   54.99% 8.17%
# 21 Realism                     1331    164        3219   41.35% 5.09%
# 22 Rococo                      294     26         626    46.96% 4.15%
# 23 Romanticism                 987     147        2105   46.89% 6.98%
# 24 Symbolism                   755     191        1358   55.60% 14.06%
# 25 Synthetic_Cubism            62      11         64     96.88% 17.19%
# 26 Ukiyo_e                     71      38         350    20.29% 10.86%
