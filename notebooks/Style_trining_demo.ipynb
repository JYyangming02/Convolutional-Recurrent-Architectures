# %%
# WikiArt Training Result Demo - Artist Classification
from IPython.display import Image, display
from IPython.display import Markdown

# Show model summary
print("\nModel and Task Summary:")
display(Markdown("""
### Model: ResNet50(pre-training) + LSTM
- Task: **Style Classification**
- Dataset: WikiArt_Style
- Number of classes: Based on `Style_class`
- Training Epochs: Up to 20 (with early stopping)
- Best model saved to: `checkpoints/style_best_model.pt`
- Using pre-train model: `checkpoints/artist_best_model.pt`
- Improved optimizer: "Ranger" suitable for image classfication task
- Evaluation includes: Loss / Accuracy curves, Confusion Matrix, Classification Report
"""))

# Show training curves
print("\nStyle Task - Training Curves:")
display(Image(filename="../checkpoints/Style_combined_metrics.png"))

# Show confusion matrix
print("\nStyle Task - Confusion Matrix:")
display(Image(filename="../checkpoints/Style_confusion_matrix.png"))
# Out:
# Model and Task Summary:
# ### Model: ResNet50(pre-training) + LSTM
# - Task: **Style Classification**
# - Dataset: WikiArt_Style
# - Number of classes: Based on `Style_class`
# - Training Epochs: Up to 20 (with early stopping)
# - Best model saved to: `checkpoints/style_best_model.pt`
# - Using pre-train model: `checkpoints/artist_best_model.pt`
# - Improved optimizer: "Ranger" suitable for image classfication task
# - Evaluation includes: Loss / Accuracy curves, Confusion Matrix, Classification Report
# Style Task - Training Curves:
# Style Task - Confusion Matrix:
